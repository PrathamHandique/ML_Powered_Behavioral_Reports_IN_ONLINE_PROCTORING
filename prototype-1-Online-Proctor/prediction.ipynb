# %%
import pandas as pd
df = pd.read_csv('final_suspicious_activity_data.csv')
df.head()
# Out:
#    frame  cpu_usage  memory_usage        fps  blink_total  voice_detected  \
# 0      0       16.5          86.5  14.650697            0               0
# 1      1       47.2          86.5  40.678745            0               0
# 2      2       36.0          86.6  69.203801            0               0
# 3      3       28.8          86.6  25.057525            0               0
# 4      4       26.9          86.6  52.862271            0               0
#
#    lip_open_count  gaze_direction  iris_gaze_direction  suspicious
# 0               0               0                    1           0
# 1               0               0                    1           0
# 2               0               0                    1           0
# 3               0               0                    1           0
# 4               0               0                    1           0

# %%
df[df['suspicious'] == 1].shape[0]
# Out:
# 1558

# %%
from sklearn.model_selection import train_test_split

# Separate features and target
X = df.drop(columns=['frame', 'suspicious', 'cpu_usage', 'fps'])  # dropping potentially correlated columns
y = df['suspicious']

# Train/test split with stratification to ensure both classes appear
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y)

# Check class distribution in the test set
test_class_distribution = y_test.value_counts()
test_class_distribution
# Out:
# 1    468
# 0    401
# Name: suspicious, dtype: int64

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# Load the data
df = pd.read_csv('final_suspicious_activity_data.csv')

# Drop unnecessary columns
X = df.drop(columns=['frame', 'suspicious','cpu_usage','fps'])  # Features
y = df['suspicious']                          # Target

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.1, random_state=42, stratify=y)

# Create and train the model
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)

# Predictions
y_pred = clf.predict(X_test)

# Evaluation
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       134
#            1       1.00      1.00      1.00       156
#
#     accuracy                           1.00       290
#    macro avg       1.00      1.00      1.00       290
# weighted avg       1.00      1.00      1.00       290
